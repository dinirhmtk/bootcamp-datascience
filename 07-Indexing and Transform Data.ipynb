# %%
# Persiapan membuat data
import pandas as pd
import random

pelajaran = ['Matematika', 'Fisika', 'Biologi', 'Kimia', 'Geologi', 'Ekonomi']
kelas = ['12A', '12B', '12C', '12D']

hasil_nilai = {
    'siswa_id' : range(1, 21),
    'pelajaran' : [random.choice(pelajaran) for i in range(20)],
    'nilai' : [random.choice(range(0, 100)) for i in range(20)],
    'jenis-kelamin' : [random.choice(['laki-laki', 'perempuan']) for i in range(20)],
    'kelas' : [random.choice(kelas) for i in range(20)]
}

df = pd.DataFrame(hasil_nilai)
df.head()
# Out:
#    siswa_id   pelajaran  nilai jenis-kelamin kelas
# 0         1     Ekonomi     17     perempuan   12B
# 1         2       Kimia     93     laki-laki   12B
# 2         3       Kimia     42     perempuan   12C
# 3         4     Ekonomi     98     perempuan   12B
# 4         5  Matematika     82     perempuan   12D

# %% [markdown]
# <h2>Soal 1: Indexing</h2>
#
# 1. Lakukan indexing terhadap dataframe untuk mengakses column nilai dan kelas saja
# 2. Lakukan indexing terhadap dataframe untuk mengakses row 5 sampai 10 beserta column pelajaran dan nilai

# %%
df.loc[:, ['nilai', 'kelas']]
# Out:
#     nilai kelas
# 0      17   12B
# 1      93   12B
# 2      42   12C
# 3      98   12B
# 4      82   12D
# 5      25   12A
# 6      89   12B
# 7      94   12B
# 8      92   12A
# 9      42   12B
# 10     40   12D
# 11     37   12D
# 12     57   12D
# 13     88   12D
# 14     82   12B
# 15     60   12B
# 16     66   12C
# 17     41   12A
# 18     61   12A
# 19      7   12C

# %%
df.loc[5:10,['pelajaran','nilai']]
# Out:
#    pelajaran  nilai
# 5    Biologi     25
# 6    Biologi     89
# 7     Fisika     94
# 8    Geologi     92
# 9      Kimia     42
# 10   Biologi     40

# %% [markdown]
# <h2>Soal 2: Filter DataFrame Dengan Boolean</h2>
#
# 1. Tampilkan semua data siswa pada mata pelajaran Ekonomi dan Fisika
# 2. Tampilkan semua data siswa yang mempunyai nilai lebih dari 50 di mata pelajaran Kimia
# 3. Tampilkan semua data yang mempunyai nilai lebih dari 70, berjnis kelamin perempuan dan di kelas 12C

# %%
display(df[(df.pelajaran =='Ekonomi') | (df.pelajaran =='Fisika')])
# Out:
#     siswa_id pelajaran  nilai jenis-kelamin kelas
# 0          1   Ekonomi     17     perempuan   12B
# 3          4   Ekonomi     98     perempuan   12B
# 7          8    Fisika     94     laki-laki   12B
# 11        12    Fisika     37     perempuan   12D
# 13        14    Fisika     88     perempuan   12D
# 18        19    Fisika     61     laki-laki   12A

# %%
display(df[(df.pelajaran =='Kimia') & (df.nilai>50)])
# Out:
#    siswa_id pelajaran  nilai jenis-kelamin kelas
# 1         2     Kimia     93     laki-laki   12B

# %%
display(df[(df.nilai>70) & (df['jenis-kelamin'] == 'perempuan') & (df.kelas == '12C')])
# Out:
# Empty DataFrame
# Columns: [siswa_id, pelajaran, nilai, jenis-kelamin, kelas]
# Index: []

# %% [markdown]
# <h2>Soal 3: Data Transformation</h2>
#
# lakukan data transformasi terhadap column 'nilai' dengan fungsi transformasi, berikut rumus dari normalisasi
#
# ![alt text](https://drive.google.com/uc?id=1wed-EbRSTA0JP1ceDp6lcKBqH2yJ4aa3)

# %%
def normalisasi(x):
    return (x-x.min())/(x.max()-x.min())
df[['nilai']].apply(normalisasi)
# Out:
#        nilai
# 0   0.109890
# 1   0.945055
# 2   0.384615
# 3   1.000000
# 4   0.824176
# 5   0.197802
# 6   0.901099
# 7   0.956044
# 8   0.934066
# 9   0.384615
# 10  0.362637
# 11  0.329670
# 12  0.549451
# 13  0.890110
# 14  0.824176
# 15  0.582418
# 16  0.648352
# 17  0.373626
# 18  0.593407
# 19  0.000000

# %%
normalisasi(df['nilai'])
# Out:
# 0     0.109890
# 1     0.945055
# 2     0.384615
# 3     1.000000
# 4     0.824176
# 5     0.197802
# 6     0.901099
# 7     0.956044
# 8     0.934066
# 9     0.384615
# 10    0.362637
# 11    0.329670
# 12    0.549451
# 13    0.890110
# 14    0.824176
# 15    0.582418
# 16    0.648352
# 17    0.373626
# 18    0.593407
# 19    0.000000
# Name: nilai, dtype: float64

# %%
df['nilai'] = df[['nilai']].apply(normalisasi)
df.head()
# Out:
#    siswa_id   pelajaran     nilai jenis-kelamin kelas
# 0         1     Ekonomi  0.109890     perempuan   12B
# 1         2       Kimia  0.945055     laki-laki   12B
# 2         3       Kimia  0.384615     perempuan   12C
# 3         4     Ekonomi  1.000000     perempuan   12B
# 4         5  Matematika  0.824176     perempuan   12D
